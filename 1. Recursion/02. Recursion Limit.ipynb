# %% [markdown]
# # <font color = 'red'>Recursion Limit</font>

# %%
def fact(n):
    if n == 0:
        return 1
    return n * fact(n-1)

# %%
n = int(input('Enter the Number : '))
print(fact(n))
# Out:
# Enter the Number : 2000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 n = int(input('Enter the Number : '))
# ----> 2 print(fact(n))
#
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
# To increase the limit for integer string conversion

import sys
sys.set_int_max_str_digits(40000)
#sys.setrecursionlimit(30000)

# %%
n = int(input('Enter the Number : '))
print(fact(n))
# Out:
# Enter the Number : 2000
# ...

# %%
n = int(input('Enter the Number : '))
print(fact(n))
# Out:
# Enter the Number : 3000
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 n = int(input('Enter the Number : '))
# ----> 2 print(fact(n))
#
# Cell In[1], line 4, in fact(n)
#       2 if n == 0:
#       3     return 1
# ----> 4 return n * fact(n-1)
#
# Cell In[1], line 4, in fact(n)
#       2 if n == 0:
#       3     return 1
# ----> 4 return n * fact(n-1)
#
#     [... skipping similar frames: fact at line 4 (2971 times)]
#
# Cell In[1], line 4, in fact(n)
#       2 if n == 0:
#       3     return 1
# ----> 4 return n * fact(n-1)
#
# RecursionError: maximum recursion depth exceeded

# %%
# To increase the recursion limit

sys.setrecursionlimit(5000)

# %%
n = int(input('Enter the Number : '))
print(fact(n))
# Out:
# Enter the Number : 3000
# ...
